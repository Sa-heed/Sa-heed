# %% [markdown]
# <a href="https://colab.research.google.com/github/Sa-heed/Sa-heed/blob/main/HAMOYE%20PROJECT%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt


Data = pd.read_csv('/content/drive/MyDrive/FoodBalanceSheets.csv',encoding='latin1')
Data.head()
print(Data.shape)
sum(Data.nunique())
print(Data.nunique())
print(Data.head(30))
# Out:
# (60943, 12)
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64
#     Area Code     Area  Item Code  ...     Y2016     Y2017     Y2018
# 0           4  Algeria       2501  ...  40551.00  41389.00  42228.00
# 1           4  Algeria       2501  ...      0.00      0.00      0.00
# 2           4  Algeria       2901  ...   3372.00   3341.00   3322.00
# 3           4  Algeria       2901  ...     94.72     92.82     91.83
# 4           4  Algeria       2901  ...     77.40     80.19     77.28
# 5           4  Algeria       2903  ...   2941.00   2921.00   2932.00
# 6           4  Algeria       2903  ...     67.37     66.11     67.10
# 7           4  Algeria       2903  ...     52.04     55.59     54.57
# ...

# %%
print('the Y2016 is :'+str(len(Data.index)))
# Out:
# the Y2016 is :60943

# %%
print(len(Data['Y2016']))
# Out:
# 60943

# %%
# Data.index('Zimbabwe')
# # k.nunique()
# # print(k)

# %% [markdown]
# Analysing

# %%
#sns.countplot(x ='Y2016',data = Data)

# %%
# sns.countplot(x='Area Code', hue='Area', data = Data)
Data['Area Code'].unique()[0:4]
# Out:
# array([ 4,  7, 53, 20])

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
Data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# sns.countplot('Element',hue='Item Code', data = Data)

# %%
sns.heatmap(Data.isnull(), yticklabels=False, cmap='viridis')

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt

data_url = "https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv"
data = pd.read_csv(data_url)
print(data.shape)
data.nunique()
print(data['fuel_unit'].count())
data.head(10)
# Out:
# (29523, 11)
# 29343
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
# 5  f1_fuel_1994_12_2_0_13  ...                1.850
# 6   f1_fuel_1994_12_2_1_1  ...                0.450
# 7  f1_fuel_1994_12_2_1_10  ...                2.360
# 8  f1_fuel_1994_12_2_2_10  ...                1.400
# 9   f1_fuel_1994_12_4_0_1  ...                1.278
#
# [10 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
a = data.groupby('fuel_unit')['fuel_unit'].count()
a
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
# print(data['fuel_unit'])
# data[['fuel_unit']] = data[['fuel_unit']].fillna(value='mcf')
data['fuel_unit'] = data['fuel_unit'].fillna(value='mcf')
data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
data['fuel_type_code_pudl']
# Out:
# 0        coal
# 1        coal
# 2        coal
# 3        coal
# 4         gas
#          ...
# 29518     gas
# 29519     gas
# 29520     gas
# 29521    coal
# 29522     gas
# Name: fuel_type_code_pudl, Length: 29523, dtype: object

# %%
data.groupby('report_year')['report_year'].count()
list(data.groupby('fuel_type_code_pudl'))
# Out:
# [('coal',                       record_id  ...  fuel_cost_per_mmbtu
#   0         f1_fuel_1994_12_1_0_7  ...                1.121
#   1        f1_fuel_1994_12_1_0_10  ...                1.120
#   2         f1_fuel_1994_12_2_0_1  ...                1.650
#   3         f1_fuel_1994_12_2_0_7  ...                1.970
#   5        f1_fuel_1994_12_2_0_13  ...                1.850
#   ...                         ...  ...                  ...
#   29503  f1_fuel_2018_12_191_1_14  ...                1.497
#   29510   f1_fuel_2018_12_403_0_2  ...                1.130
#   29516    f1_fuel_2018_12_12_0_8  ...                1.100
#   29517   f1_fuel_2018_12_12_0_10  ...                0.890
#   29521   f1_fuel_2018_12_12_1_13  ...                1.110
#
#   [8547 rows x 11 columns]),
#  ('gas',                      record_id  ...  fuel_cost_per_mmbtu
#   4       f1_fuel_1994_12_2_0_10  ...                 2.57
#   10       f1_fuel_1994_12_4_0_2  ...                13.90
# ...

# %%
data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  ...  fuel_cost_per_mmbtu
# fuel_type_code_pudl                          ...
# coal                  f1_fuel_1994_12_1_0_7  ...                1.121
# gas                  f1_fuel_1994_12_2_0_10  ...                2.570
# nuclear               f1_fuel_1994_12_2_1_1  ...                0.450
# oil                   f1_fuel_1994_12_6_0_2  ...                5.469
# other                f1_fuel_1994_12_11_0_6  ...                2.335
# waste                 f1_fuel_1994_12_9_0_3  ...                1.072
#
# [6 rows x 10 columns]

# %%
data.groupby('fuel_type_code_pudl').head()
# Out:
#                     record_id  ...  fuel_cost_per_mmbtu
# 0       f1_fuel_1994_12_1_0_7  ...                1.121
# 1      f1_fuel_1994_12_1_0_10  ...                1.120
# 2       f1_fuel_1994_12_2_0_1  ...                1.650
# 3       f1_fuel_1994_12_2_0_7  ...                1.970
# 4      f1_fuel_1994_12_2_0_10  ...                2.570
# 5      f1_fuel_1994_12_2_0_13  ...                1.850
# 6       f1_fuel_1994_12_2_1_1  ...                0.450
# 10      f1_fuel_1994_12_4_0_2  ...               13.900
# 12      f1_fuel_1994_12_4_0_5  ...                1.900
# 14      f1_fuel_1994_12_6_0_2  ...                5.469
# 19     f1_fuel_1994_12_6_0_14  ...                5.770
# 21      f1_fuel_1994_12_6_1_8  ...                5.187
# 23     f1_fuel_1994_12_6_1_11  ...                5.604
# 25     f1_fuel_1994_12_6_1_14  ...                5.605
# 28      f1_fuel_1994_12_7_0_3  ...                2.820
# 30      f1_fuel_1994_12_7_0_8  ...                2.650
# ...

# %%
data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  ...  fuel_cost_per_mmbtu
# fuel_type_code_pudl                          ...
# coal                  f1_fuel_1994_12_1_0_7  ...                1.121
# gas                  f1_fuel_1994_12_2_0_10  ...                2.570
# nuclear               f1_fuel_1994_12_2_1_1  ...                0.450
# oil                   f1_fuel_1994_12_6_0_2  ...                5.469
# other                f1_fuel_1994_12_11_0_6  ...                2.335
# waste                 f1_fuel_1994_12_9_0_3  ...                1.072
#
# [6 rows x 10 columns]

# %%
 data['fuel_type_code_pudl'][0:10]
# Out:
# 0       coal
# 1       coal
# 2       coal
# 3       coal
# 4        gas
# 5       coal
# 6    nuclear
# 7       coal
# 8       coal
# 9       coal
# Name: fuel_type_code_pudl, dtype: object

# %%
data_df1 = data.iloc[0:19000]    #.reset_index(drop=True)
data_df1.head()
data_df2 = data.iloc[19000:]  #.reset_index(drop=True)
assert len(data)==(len(data_df1) + len(data_df2))
print(data_df1.head())
print(data_df2())
